# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(-5, 5, 100)

# %%
def plot(X, y, color, label):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    # plot the function
    for Y, c, l in zip(y, color, label):
        plt.plot(X,Y, c, label=l)

    # show the plot
    plt.legend()
    plt.show()

# %%
y = 1 / (1 + np.exp(-X))

plot(X, [y], ['red'], ['Sigmoid'])

# %%
y1 = -np.log(X)
y2 = -np.log(1 - X)
y3 = np.log(X)
y4 = np.log(1-X)

plot(X, 
     [y1, y2, y3, y4], 
     ['red', 'blue', 'green', 'brown'], 
     ['-log(x)','-log(1-x)', 'log(x)', 'log(1-x)'])
# Out:
# C:\Users\Sajjad Ali\AppData\Local\Temp\ipykernel_3760\3755264342.py:1: RuntimeWarning: invalid value encountered in log
#   y1 = -np.log(X)
# C:\Users\Sajjad Ali\AppData\Local\Temp\ipykernel_3760\3755264342.py:2: RuntimeWarning: invalid value encountered in log
#   y2 = -np.log(1 - X)
# C:\Users\Sajjad Ali\AppData\Local\Temp\ipykernel_3760\3755264342.py:3: RuntimeWarning: invalid value encountered in log
#   y3 = np.log(X)
# C:\Users\Sajjad Ali\AppData\Local\Temp\ipykernel_3760\3755264342.py:4: RuntimeWarning: invalid value encountered in log
#   y4 = np.log(1-X)
