# %%
from array import *

# %%
arr = array('i', [1,2,3,4])
print(arr)
print(arr.buffer_info())
arr.append(5)
print(arr)
arr.insert(2,12)
print(arr)
# Out:
# array('i', [1, 2, 3, 4])
# (140283850810672, 4)
# array('i', [1, 2, 3, 4, 5])
# array('i', [1, 2, 12, 3, 4, 5])

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.array(24)
# Out:
# array(24)

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.array([[1,2,3], [4,5,6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr = np.array([[[1,2,3], [4,5,6]]])
print(arr.ndim)
# Out:
# 3

# %%
arr = np.array([1,2,3,4,5], ndmin=5)
print(arr.ndim, arr)
# Out:
# 5 [[[[[1 2 3 4 5]]]]]

# %%
arr = np.array([1.1,2.1,3.1,4.4])
newarr = arr.astype('i')
print(newarr)
# Out:
# [1 2 3 4]

# %%
arr = np.array([[1,2,3], [4,5,6]])
arr.shape
# Out:
# (2, 3)

# %%
arr = np.array([i for i in range(12)]).reshape(3,4)
print(arr.shape[1])
# Out:
# 4

# %%
import pandas as pd

# %%
a = {
    'val' : [1,2,3,4,5],
    'name': ['a', 'b', 'c', 'd', 'e']
}
pd.Series(a)
# Out:
# val     [1, 2, 3, 4, 5]
# name    [a, b, c, d, e]
# dtype: object

# %%
f = pd.DataFrame(a, index=['a', 'b', 'c', 'd', 'e'])
print(f)
print(f.loc[['a', 'c', 'e']])
# Out:
#    val name
# a    1    a
# b    2    b
# c    3    c
# d    4    d
# e    5    e
#    val name
# a    1    a
# c    3    c
# e    5    e

# %%
a = {
    'val' : [1,2,3,4,5, None],
    'name': [None, None, 1, 2, None, None],
    'sal' : [None, 200, None, None, None, None]
}
f = pd.DataFrame(a)
print(f)
print(f.dropna(axis=0, thresh=2))
# Out:
#    val  name    sal
# 0  1.0   NaN    NaN
# 1  2.0   NaN  200.0
# 2  3.0   1.0    NaN
# 3  4.0   2.0    NaN
# 4  5.0   NaN    NaN
# 5  NaN   NaN    NaN
#    val  name    sal
# 1  2.0   NaN  200.0
# 2  3.0   1.0    NaN
# 3  4.0   2.0    NaN

# %%
a = {
    'val' : [1,2,3,4,5, None],
    'name': [None, None, 1, 2, None, None],
    'sal' : [None, 200, None, None, None, None]
}
f = pd.DataFrame(a)
print(f)
print(f.dropna(axis=0, subset=['val']))

df = pd.read_csv('BCancer.csv')
df = df.iloc[:, 1:-1]
# Out:
#    val  name    sal
# 0  1.0   NaN    NaN
# 1  2.0   NaN  200.0
# 2  3.0   1.0    NaN
# 3  4.0   2.0    NaN
# 4  5.0   NaN    NaN
# 5  NaN   NaN    NaN
#    val  name    sal
# 0  1.0   NaN    NaN
# 1  2.0   NaN  200.0
# 2  3.0   1.0    NaN
# 3  4.0   2.0    NaN
# 4  5.0   NaN    NaN

# %%
df.corr()
# Out:
#                          radius_mean  texture_mean  smoothness_mean  \
# radius_mean                 1.000000      0.323782         0.170581
# texture_mean                0.323782      1.000000        -0.023389
# smoothness_mean             0.170581     -0.023389         1.000000
# compactness_mean            0.506124      0.236702         0.659123
# concavity_mean              0.676764      0.302418         0.521984
# concave points_mean         0.822529      0.293464         0.553695
# symmetry_mean               0.147741      0.071401         0.557775
# fractal_dimension_mean     -0.311631     -0.076437         0.584792
# radius_se                   0.679090      0.275869         0.301467
# texture_se                 -0.097317      0.386358         0.068406
# perimeter_se                0.674172      0.281673         0.296092
# area_se                     0.735864      0.259845         0.246552
# smoothness_se              -0.222600      0.006614         0.332375
# ...

# %%
df[['diagnosis', 'radius_mean']]
# Out:
#     diagnosis  radius_mean
# 0           M        17.99
# 1           M        20.57
# 2           M        19.69
# 3           M        11.42
# 4           M        20.29
# ..        ...          ...
# 564         M        21.56
# 565         M        20.13
# 566         M        16.60
# 567         M        20.60
# 568         B         7.76
#
# [569 rows x 2 columns]

# %%
df.iloc[564, 0]
# Out:
# 'M'
