# %%
import matplotlib as mpl
# %matplotlib notebook

# %%
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
#Basic Plotting given below

# %%
plt.figure()
plt.plot(3,2,'s')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(1.5, 1.5, 'o')
plt.plot(2,2,'o')
plt.plot(2.5, 2.5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(3,2,'o')
plt.plot(3,3,'o')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 6.0, 0.0, 10.0)

# %%
#scatterplots given below cells

# %%
#Pyplot is keeping track of the axis objects for you. 
#The function declaration from most of the functions in matplotlib end with an open set of keyword arguments. 
#There are a lot of different properties you can control through these keyword arguments.
plt.gca?
#plt.gcf?

# %%
#single color graph
import numpy as np
x = np.array([1,2,3,4,5,6,7,8])
y = x 

plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# color assign by us
import numpy as np

x = np.array([1,2,3,4,5,6,7,8])
y = x

colors = ['green']*(len(x)-1)
colors.append('red')

print(colors)

plt.figure()
# s is size of dot which is appearing on graph you may change it. Try it yourself
plt.scatter(x,y,s=100, c=colors)
# Out:
# ['green', 'green', 'green', 'green', 'green', 'green', 'green', 'red']
# <img src="data:image/png;base64,..." width="640">

# %%
# color assign by us. Using index values
# x[:2], y[:2] means first two
# x[2:], y[2:] means except first two 
# you may change color name as you like
plt.figure()
plt.scatter(x[:2], y[:2], c='blue')
plt.scatter(x[2:], y[2:], c='red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# properties of axes
plt.xlabel('The number of times the child kicked a ball')
plt.ylabel('The grade of the student')
plt.title('Relationship between ball kicking and grades')
# Out:
# Text(0.5, 1, 'Relationship between ball kicking and grades')

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.legend(loc=4, frameon=False, title='Legend')
# Out:
# No handles with labels found to put in legend.

# %%
# Line plot as follows:

# %%
import numpy as np

linear_data = np.array([1,2,3,4,5,6,7])
quadratic_data = linear_data**2

plt.figure()
plt.plot(linear_data, '-o', quadratic_data, '--o')

## index of the series as the x value
## auto color difference
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
# it will appear on above graph
plt.xlabel('Some data')
plt.ylabel('Some other data')
plt.title('A title')
plt.legend(['Baseline', 'Competition'])

# %%
# it will appear on above graph
plt.plot([10, 15, 25], '--s')

# %%
# it will appear on above graph
plt.legend(['Baseline', 'Competition', 'us'])

# %%
# it will appear on above graph
plt.fill_between(range(len(linear_data)), 
                      linear_data, quadratic_data,
                      facecolor='blue',
                      alpha=0.1)
# Full list of functions as such can be found on matplotlib document:
# https://matplotlib.org/api/pyplot_summary.html

# %%
# it will appear on above graph
plt.title("Quadratic ($x^2$) v.s. Linear ($x$) performance")
# Out:
# Text(0.5, 1, 'Quadratic ($x^2$) v.s. Linear ($x$) performance')

# %%
# bar charts as follows:

# %%
plt.figure()
xvals = range(len(linear_data))
print(xvals)
plt.bar(xvals,linear_data, width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# range(0, 7)
# <BarContainer object of 7 artists>

# %%
# it will appear on above graph
new_xvals=[]
for item in xvals:
    new_xvals.append(item+0.3)
    
plt.bar(new_xvals, quadratic_data, width=0.3, color='red')
# Out:
# <BarContainer object of 7 artists>

# %%
plt.figure()
from random import randint
linear_err = [randint(0,5) for x in range (len(linear_data))]
plt.bar(xvals, quadratic_data, width=0.3, yerr=linear_err)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 7 artists>

# %%
print(linear_err)
# Out:
# [1, 1, 1, 5, 0, 5, 3]

# %%
plt.figure()
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width=0.3, color='b')
plt.bar(xvals, quadratic_data, width=0.3, bottom=linear_data, color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 7 artists>

# %%
# Horizontal bar plot as follows:

# %%
# bottom to left and width to height

plt.figure()
xvals = range(len(linear_data))
plt.barh(xvals, linear_data, height=0.3, color='b')
plt.barh(xvals, quadratic_data, height=0.3, left=linear_data, color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 7 artists>

# %%
# bar plot optimization

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')

for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, 
                   bar.get_height()-5,
                   str(int(bar.get_height())) + '%',
                   ha='center', color='w',fontsize=11)
    
bars[0].set_color('#1F77B4')
plt.xticks(pos,languages)

#plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

#TODO: remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=False, labelbottom=True)

# TODO: remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Subplots as follows:

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

plt.subplot?

# %%
plt.figure()
# subplot with 1 row, 2 columns, and current axis is 1st subplot axes
plt.subplot(1, 2, 1)

linear_data = np.array([1,2,3,4,5,6,7,8])

plt.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# it will appear on above graph

exponential_data = linear_data**2 

# subplot with 1 row, 2 columns, and current axis is 2nd subplot axes
plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-o')
# Out:
# C:\Users\Safdar Ali\Python\envs\py36\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# it will appear on above graph

# plot exponential data on 1st subplot axes
plt.subplot(1, 2, 1)
plt.plot(exponential_data, '-x')
# Out:
# C:\Users\Safdar Ali\Python\envs\py36\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
#There would be a big problem with misleading the reader if we didn't find a way to lock axis between two plots. 
#When you create a new subplot you are able to share the x, y, or both axis using the share x and share y parameters.

plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(exponential_data, '-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# the right hand side is equivalent shorthand syntax
plt.subplot(1,2,1) == plt.subplot(121)
# Out:
# C:\Users\Safdar Ali\Python\envs\py36\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# True

# %%
# create a 3x3 grid of subplots
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9)) = plt.subplots(3, 3, sharex=True, sharey=True)
# plot the linear_data on the 5th subplot axes 
ax5.plot(linear_data, '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# set inside tick labels to visible
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
# necessary on some systems to update the plot
plt.gcf().canvas.draw()

# %%
# Histograms as follows
#A histogram is a bar chart which shows the frequency of a given phenomena. A great example are probability distributions.

# %%
#Let's pull some samples from the normal distribution and plot four different histograms as subplots. 
#First I'll create our 2 x 2 grade of axis objects. 
#In this case, we don't want to share the y-axis between the plots since we're intentionally looking at a number of different sizes of samples.

# create 2x2 grid of axis subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

# draw n = 10, 100, 1000, and 10000 samples from the normal distribution and plot corresponding histograms
for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# repeat with number of bins set to 100
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample, bins=100)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Scatter Plot as follows

# %%
# A more flexible "GridSpec" layout for subplots. The GridSpec allows you to map axes over multiple cells in a grid.

plt.figure()
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3,3)

top_histogram = plt.subplot(gspec[0,1:])
side_histogram = plt.subplot(gspec[1:,0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# it will appear on above graph

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
lower_right.scatter(X,Y)
top_histogram.hist(X, bins=100)
s = side_histogram.hist(Y, bins=100, orientation='horizontal')

# %%
# it will appear on above graph

top_histogram.clear()
top_histogram.hist(X, bins=100, density=True)
side_histogram.clear()
side_histogram.hist(Y, bins=100, orientation='horizontal', density=True)

side_histogram.invert_xaxis()

# %%
# it will appear on above graph

for ax in [top_histogram, lower_right]:
    ax.set_xlim(0,1)
for ax in [side_histogram,lower_right]:
    ax.set_ylim(-5,5)

# %%
# Box Plot as follows:

# %%
import numpy as np
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample,
                  'random':random_sample,
                  'gamma':gamma_sample})

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.013373      0.501587      2.008833
# std        0.989875      0.287386      1.408717
# min       -3.646509      0.000012      0.013893
# 25%       -0.690309      0.253641      0.947396
# 50%       -0.009152      0.502191      1.708752
# 75%        0.659610      0.751106      2.708749
# max        3.373024      0.999981     13.343799

# %%
plt.figure()
_=plt.boxplot(df['normal'], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.clf()
_=plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')

# %%
plt.figure()
_=plt.hist(df['gamma'], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#An inset plot showing a distribution as a histogram layered on top of a box plot.

import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax2.yaxis.tick_right()

# %%
plt.figure()
_=plt.boxplot([df['normal'],df['random'],df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Heat Maps as follows:

# %%
plt.figure()

Y = np.random.normal(loc=0.0,scale=1.0,size=10000)
X = np.random.random(size=10000)
_ = plt.hist2d(X, Y, bins=25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

Y = np.random.normal(loc=0.0,scale=1.0,size=10000)
X = np.random.random(size=10000)
_ = plt.hist2d(X, Y, bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# it will effect above graph

plt.colorbar()

# %%
# Animations as follows:

# %%
import matplotlib.animation as animation

n = 100
x = np.random.randn(n)

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n = {}'.format(curr), [3,27])
    # Another text function called annotate.
    # This places text at a certain position in the chart and we'll use it to show how many samples are currently being rendered to the screen.

# %%
fig=plt.figure()
a = animation.FuncAnimation(fig,update,interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Pandas Visualization as follows:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Safdar Ali\Python\envs\py36\lib\site-packages\matplotlib\cbook\__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "C:\Users\Safdar Ali\Python\envs\py36\lib\site-packages\matplotlib\animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
# see the pre-defined styles provided.
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
# use the 'seaborn-colorblind' style
plt.style.use('seaborn-colorblind')

# %%
np.random.seed(123)

df = pd.DataFrame({'A': np.random.randn(365).cumsum(0), 
                   'B': np.random.randn(365).cumsum(0) + 20,
                   'C': np.random.randn(365).cumsum(0) - 20}, 
                  index=pd.date_range('1/1/2017', periods=365))
df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02 -0.088285  21.803332 -16.659325
# 2017-01-03  0.194693  20.835588 -17.055481
# 2017-01-04 -1.311601  21.255156 -17.093802
# 2017-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot(); # add a semi-colon to the end of the plotting call to suppress unwanted output
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# We can select which plot we want to use by passing it into the 'kind' parameter.

df.plot('A','B', kind = 'scatter');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'''
kind :

'line' : line plot (default)
'bar' : vertical bar plot
'barh' : horizontal bar plot
'hist' : histogram
'box' : boxplot
'kde' : Kernel Density Estimation plot
'density' : same as 'kde'
'area' : area plot
'pie' : pie plot
'scatter' : scatter plot
'hexbin' : hexbin plot '''
# Out:
# "\nkind :\n\n'line' : line plot (default)\n'bar' : vertical bar plot\n'barh' : horizontal bar plot\n'hist' : histogram\n'box' : boxplot\n'kde' : Kernel Density Estimation plot\n'density' : same as 'kde'\n'area' : area plot\n'pie' : pie plot\n'scatter' : scatter plot\n'hexbin' : hexbin plot "

# %%
# create a scatter plot of columns 'A' and 'C', with changing color (c) and size (s) based on column 'B'
df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.box();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist(alpha=0.7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.kde();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# pandas.plotting as follows:

columns=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name']
iris = pd.read_csv('http://scv.bu.edu/examples/python/data_visualization/iris.data.csv')
iris.columns=columns
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          4.9         3.0          1.4         0.2  Iris-setosa
# 1          4.7         3.2          1.3         0.2  Iris-setosa
# 2          4.6         3.1          1.5         0.2  Iris-setosa
# 3          5.0         3.6          1.4         0.2  Iris-setosa
# 4          5.4         3.9          1.7         0.4  Iris-setosa

# %%
pd.plotting.scatter_matrix(iris);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
pd.plotting.parallel_coordinates(iris, 'Name');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Seaborn as follows:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50,150,5), label='v1');
plt.hist(v2, alpha=0.7, bins=np.arange(-50,150,5), label='v2');
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot a kernel density estimation over a stacked barchart
plt.figure()
plt.hist([v1, v2],  density=True);
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
# we can pass keyword arguments for each individual component of the plot
sns.distplot(v3, hist_kws={'color': 'Teal'}, kde_kws={'color': 'Navy'});
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(v1, v2, alpha=0.4);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
grid = sns.jointplot(v1, v2, alpha=0.4);
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(v1, v2, kind='hex');
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# set the seaborn style for all the following plots
sns.set_style('white')

sns.jointplot(v1, v2, kind='kde', space=0);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
columns=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name']
iris = pd.read_csv('http://scv.bu.edu/examples/python/data_visualization/iris.data.csv')
iris.columns=columns
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          4.9         3.0          1.4         0.2  Iris-setosa
# 1          4.7         3.2          1.3         0.2  Iris-setosa
# 2          4.6         3.1          1.5         0.2  Iris-setosa
# 3          5.0         3.6          1.4         0.2  Iris-setosa
# 4          5.4         3.9          1.7         0.4  Iris-setosa

# %%
sns.pairplot(iris, hue='Name', diag_kind='kde', size=2);
# Out:
# C:\Users\Safdar Ali\Python\envs\py36\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="932">

# %%
plt.figure(figsize=(8,6))
plt.subplot(121)
sns.swarmplot('Name', 'PetalLength', data=iris);
plt.subplot(122)
sns.violinplot('Name', 'PetalLength', data=iris);
# Out:
# <img src="data:image/png;base64,..." width="800">
